# %%
import twint
import pandas as pd

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://xlububankx:41xwyt6ohrXkxTWi@cluster0.qjyti.mongodb.net/training_database?retryWrites=true&w=majority')
col = client['training_database']['training_data']

# %%
c = twint.Config()
c.Search = "#ร้องข้ามกําแพง"
c.Min_likes = 5
c.Pandas = True

twint.run.Search(c)
tweets_df = twint.storage.panda.Tweets_df
tweets_df["label"] = "none"
tweets_df = tweets_df[tweets_df["language"]=="th"]

data = tweets_df.to_dict(orient='records')

col.insert_many(data)
# Out:
# 1514670454845292552 2022-04-15 01:22:32 +0700 <hasaddd> ขึ้นต้นมา คำแรก รู้เลย #โมอมีนา เสียงเธอเป็นเอกลักษณ์มากกกก ร้องเพลงเพราะ ตอนนี้หมดสัญญาช่องแล้วด้วย อิสระเต็มตัว . ปล.แกงส้ม และ ดาว เป็นคู่ที่น่ารักสุดๆ เสียงเพราะมากทั้งคู่ . #ร้องข้ามกำแพง  https://t.co/FQrLsLgiI4
# 1514653046600781824 2022-04-15 00:13:21 +0700 <iwannabeame> ไม่ว่าจะผ่านไปกี่10ปี เสียงพี่รุจยังเหมือนเดิมไม่มีเปลี่ยน เสียงหลบคือนัมเบอร์วัน!!  #ร้องข้ามกำแพง #รุจศุภรุจ  https://t.co/mfhUDe1djy
# 1514646653726507015 2022-04-14 23:47:57 +0700 <GeneLabRecords> จ๋าย ไททศมิตร Feat. พี สะเดิด - อยากหยุดเวลา original by ศรัณย่า ส่งเสริมสวัสดิ์  :  https://t.co/iouc4jB5Ev  ในรายการ ร้องข้ามกำแพง the wall song @thewallsong   #จ๋ายไททศมิตร #พีสะเดิด #อยากหยุดเวลา #ร้องข้ามกำแพง #thewallsong
# 1514644210364084224 2022-04-14 23:38:15 +0700 <kapookdotcom> นักร้องหลังกำแพงสาวคนนี้ ทำอึ้งกันทั้งรายการ คำใบ้ชัดมาก !  https://t.co/fObHSq9qnh #TheWallSong #ร้องข้ามกำแพง #kapook
# ...

# %%
c = twint.Config()
c.Search = "#อักเสบ"
c.Min_likes = 5
c.Pandas = True

twint.run.Search(c)
tweets_df = twint.storage.panda.Tweets_df
tweets_df["label"] = "health"
tweets_df = tweets_df[tweets_df["language"]=="th"]

data = tweets_df.to_dict(orient='records')

col.insert_many(data)
# Out:
# 1434060867125972993 2021-09-04 14:48:48 +0700 <ppongx> มือเก๊าเดี้ยงน่ะ #เอ็นข้อมือ #อักเสบ 😭  https://t.co/e52OjeDZP8
# 1258760769589727232 2020-05-08 21:08:48 +0700 <eXaMPle_me_too> เจอเคสเป็นเริม แล้วไปให้คนแก่พ่นหมากมาให้ #อักเสบ สิคะ  ถามว่าทำไมมาป่านนี้ บอกว่า จะรอดูว่าที่พ่นหมากมามันจะแห้งมั้ย สรุปมันไม่แห้ง หึหึ   ครั้งที่ล้าน กับเรื่องเริม 👎👎
# 1214006982803222528 2020-01-06 09:13:14 +0700 <eXaMPle_me_too> เริ่มเจ็บคอเพราะดื่มแอลกอฮอล์ในช่วงเทศกาลหนักไปหน่อย แล้วหายากินเอง แล้วคุณกินยาปฏิชีวนะ (ยาฆ่าเชื้อ) โอ๊ยยยย คุณติดเชื้ออะไรคะถึงต้องกินฆ่าเชื้อ !! ถ้ายังแยกไม่ออกระหว่าง #อักเสบ กับ #ติดเชื้อ คนไทยก็ยังมีภาวะเสี่ยงดื้อยาสูงต่อไป   ครั้งที่เท่าไรไม่รู้ที่บอก เฮ้ออออ
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
c = twint.Config()
c.Search = "#สาวสองกรุงเทพ"
c.Min_likes = 5
c.Pandas = True

twint.run.Search(c)
tweets_df = twint.storage.panda.Tweets_df
tweets_df["label"] = "sexual"
tweets_df = tweets_df[tweets_df["language"]=="th"]

data = tweets_df.to_dict(orient='records')

col.insert_many(data)
# Out:
# 1513197065203249153 2022-04-10 23:47:48 +0700 <kchkr55071403> #สาวสองมีงู #สาวสองนัดเย็ด #อยากโดนเย็ด #อมควย #สาวสองกรุงเทพ
# 1512810934191812614 2022-04-09 22:13:28 +0700 <Nongkim1999> รสชาติของความรัก .. ไม่อร่อยเท่าเบียร์ 🍻 และเบียร์ ก็ไม่อร่อยเท่าเรา ขอบคุณค่ะ😆 #สาวสอง #รัชดา #ดินแดง #ลาดพร้าว  #พระราม9 #สาวสองกรุงเทพ #กะเทย #ห้วยขวาง  https://t.co/RrHerMZdst
# 1512323200356524032 2022-04-08 13:55:23 +0700 <bell2546zzz> อยากจุกบ้างจัง เบื่อแล้วลองรุก #กทม #รามคำแหง53 #สาวสองกรุงเทพ  https://t.co/OUhA7ofFki
# 1512277018691645442 2022-04-08 10:51:52 +0700 <tildaktkl> น้ำผลไม้เองค่า เเต่ดื่มเเล้วไม่เหมือนเดิมนะ #สาวสอง #สาวสองกรุงเทพ #ladyboyBkk  https://t.co/8sTekpTk55
# 1511955008006152193 2022-04-07 13:32:19 +0700 <Ladyboymora> ว่างนะ มาจิ 🤣🤣#สาวสอง #สาวสองกรุงเทพ #เย็ด #fwb #fwbกรุงเทพ #ดินแดง #นัดเย็ด #สาวสอง #อนุเสาวรีย์ #อารีย์ #สาวสองรับงานกทม  #นัดกอด  #เงี่ยน 😁😁😁😁  https://t.co/lmGDyZBzVG
# ...

# %%
c = twint.Config()
c.Search = "#ขบวนเสด็จ"
c.Min_likes = 5
c.Pandas = True

twint.run.Search(c)
tweets_df = twint.storage.panda.Tweets_df
tweets_df["label"] = "politics"
tweets_df = tweets_df[tweets_df["language"]=="th"]

data = tweets_df.to_dict(orient='records')

col.insert_many(data)
# Out:
# 1515042404461867008 2022-04-16 02:00:32 +0700 <juniorza> มึงแม่กูวัยเกือบ 60โดนตำรวจกักตัว 1 ชม. แล้วโดนปรับ 1,000.- โดนค้นโทรศัพท์ ค้นเฟสบุ๊ค ไลน์โดนถ่ายรูปประวัติ เพราะข้อหาก่อกวนขบวนเสด็จ ทั้งๆที่แม่กูพึ่งกลับจากทำบุญ แล้วขับรถหลงทางไปตรงเส้นขบวนเสด็จ(ไม่รู้มาก่อน) จากการที่ตำรวจแม่งไม่กั้นให้ชัดเจน โบกแบบโง่ๆ งงมากกกนะ #ขบวนเสด็จ
# 1515037659172810756 2022-04-16 01:41:40 +0700 <LittleMinni3z> จะมารับเส^7 มั้ย #ขบวนเสด็จ
# 1515035422296260610 2022-04-16 01:32:47 +0700 <TopTrendThai> Twitter Trend 2022-04-16 01:32:46 1. #คิดถึงหยิ่นวอร์พร้อม 2. #2ndPREMIUMLIVE_B_DAY1 3. #ขบวนเสด็จ 4. #แอบหลงรักEP10 5. #StarInMyMindEP2
# 1515034743410429953 2022-04-16 01:30:05 +0700 <jeysy_mn> แล้วแกดูเค้าดิมือไม้คือไปแล้วอ่ะ เค้าคงกลัวมากๆแล้วอ่ะ กินแมคอยู่ดีๆก็โดนอุ้มมึงว่ามันควรมั้ย #ขบวนเสด็จ
# 1515034724804136960 2022-04-16 01:30:01 +0700 <oonging_zz> มึง ทุกวันนี้เอาอะไรมาให้กู ภาคภูมิใจในความเป็นไทย?  #ขบวนเสด็จ
# ...

# %%
c = twint.Config()
c.Search = "#ราศี"
c.Min_likes = 5
c.Pandas = True

twint.run.Search(c)
tweets_df = twint.storage.panda.Tweets_df
tweets_df["label"] = "religion"
tweets_df = tweets_df[tweets_df["language"]=="th"]

data = tweets_df.to_dict(orient='records')

col.insert_many(data)
# Out:
# 1513179244641517570 2022-04-10 22:37:00 +0700 <mutaru_tarot> ให้ไพ่เล่าเรื่อง🪄🔮 #pickacard   หายใจเข้าลึกๆ แล้วหลับตานึกถึงสิ่งศักดิ์สิทธิ์ที่นับถือก่อนนะ แล้วค่อยลืมตาตั้งจิตหยิบไพ่สักหนึ่งใบ แล้วดูคำตอบหน้าถัดไป  #ดูดวงกับพี่หมอบอม #mutaru_tarot   #ดูดวง #ดูดวงความรัก #ดูดวงการงาน #ดูดวงออนไลน์ #รวย  #ดูดวงฟรี #ไพ่ยิปซี #หมอดู #ราศี  https://t.co/Layf0yYEp8
# 1512962168085692417 2022-04-10 08:14:25 +0700 <mutaru_tarot> ความรักที่เราจะเจอ!❤️💕 #pickacard   หายใจเข้าลึกๆ แล้วหลับตานึกถึงสิ่งศักดิ์สิทธิ์ที่นับถือก่อนนะ แล้วค่อยลืมตาตั้งจิตหยิบไพ่สักหนึ่งใบ แล้วดูคำตอบหน้าถัดไป  #ดูดวงกับพี่หมอบอม #mutaru_tarot   #ดูดวง #ดูดวงความรัก #ดูดวงการงาน #ดูดวงออนไลน์ #รวย  #ดูดวงฟรี #ไพ่ยิปซี #หมอดู #ราศี  https://t.co/k7qQHyevyH
# ...

# %%
c = twint.Config()
c.Search = "#อาหลับ"
c.Min_likes = 5
c.Pandas = True

twint.run.Search(c)
tweets_df = twint.storage.panda.Tweets_df
tweets_df["label"] = "ethnicity"
tweets_df = tweets_df[tweets_df["language"]=="th"]

data = tweets_df.to_dict(orient='records')

col.insert_many(data)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'language'
#
# ...

# %%
col.update_many({"search": "#ฉีดวัคซีน"}, {"$set":{"label": "health"}})
